# %%
from functools import lru_cache

@lru_cache(maxsize=None)
def pi(n) :
    result = []
    for i in range (3, 100) :
        for j in range (1, 100) :
            if 3.14 < i/ j < 3.15 :
                result.append((i, j))
                if len(result) == 1 :
                    break
    return result      

print(pi(2))
# Out:
# [(22, 7), (44, 14), (66, 21), (85, 27), (88, 28)]

# %%
from functools import lru_cache

@lru_cache(maxsize=None)
def pi(n) :
    for i in range (3, 100) :
        for j in range (1, 100) :
            if 3.14 < i/ j < 3.15 :
                return j 


print(pi(2))
# Out:
# 7

# %%
from math import pi, floor

print(pi)
n = 11
a = int('3141592653589793'[:n+1])
print(a)
b = 10**n 
print(a / b)

q = 1
print(floor(a / b))
print(floor((a + 1) / b))

while True :
    if floor(q * a / b) != floor(q * (a + 1 )/ b) :
        # if q * (pi + 1) % pow > 0 :
            print(q)
            break
    q += 1
# Out:
# 3.141592653589793
# 314159265358
# 3.14159265358
# 3
# 3
# 265381

# %%
from math import floor


N = 11
q = 1


pi = int('314159265358'[0:N + 1])
pow = 10 ** N


while True :
    if floor(q * pi / pow) != floor(q * (pi + 1 )/ pow) :
        # if q * (pi + 1) % pow > 0 :
            print(q)
            break
    q += 1
# Out:
# 265381
