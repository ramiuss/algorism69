# %%
# 나르시스트 수는 어떤 수에서 각각의 수에 그 수의 자릿수 만큼의 거듭제곱을 해서 더한 값이 그 수와 같으면
# 나르시스트 수라고 한다..

# %%
a = 153 
print(len(str(a)))

for i in str(a) :
    print(i, end=',')
# Out:
# 3
# 1,5,3,

# %%
a = 153 

count = 0
for i in str(a) :
    count += int(i) ** len(str(a)) 
if count == a :
    print(f'{a} 는 나르시스트 수 입니다')
# Out:
# 153 는 나르시스트 수 입니다

# %%
# 8진수 수 2자리수 이상으로 8개의 나르시스트 수를 구하시오..

# %%
a = 153

print(oct(a))  # 8진수가 0o 가 붙어서 나온다..따라서
print(oct(153)[2:])  # 슬라이스를 이용해서 수만 골라낸다...하지만 문자열이다.
# Out:
# 0o231
# 231

# %%
a = 153
b = oct(a)
print(b, type(b))

count = 0
for i in b[2:] :
    count += int(i) ** len(b)
if count == b[2:] :
    print(f'{b} 는 8진수에서 나르시스트 입니다')
else :
    print(f'{b} 는 8진수에서 나르시스트 수가 아닙니다.')
# Out:
# 0o231 <class 'str'>
# 0o231 는 8진수에서 나르시스트 수가 아닙니다.

# %%
def convert_octal(n) :
    return oct(n)[2:]

print(convert_octal(4))
print(convert_octal(14))
print(convert_octal(24))
print(convert_octal(4224))
# Out:
# 4
# 16
# 30
# 10200

# %%
data = []

for i in range(1, 100000) :
    data.append(oct(i)[2:])
print(data)

result = []
for i in data :
    count = 0
    for j in str(i) :
        count += int(j) ** len(str(i))
    if oct(count)[2:] == i :
        if len(oct(count)[2:]) >= 2 :
            result.append(i)

print(result[:8])
# Out:
# ['1', '2', '3', '4', '5', '6', '7', '10', '11', '12', '13', '14', '15', '16', '17', '20', '21', '22', '23', '24', '25', '26', '27', '30', '31', '32', '33', '34', '35', '36', '37', '40', '41', '42', '43', '44', '45', '46', '47', '50', '51', '52', '53', '54', '55', '56', '57', '60', '61', '62', '63', '64', '65', '66', '67', '70', '71', '72', '73', '74', '75', '76', '77', '100', '101', '102', '103', '104', '105', '106', '107', '110', '111', '112', '113', '114', '115', '116', '117', '120', '121', '122', '123', '124', '125', '126', '127', '130', '131', '132', '133', '134', '135', '136', '137', '140', '141', '142', '143', '144', '145', '146', '147', '150', '151', '152', '153', '154', '155', '156', '157', '160', '161', '162', '163', '164', '165', '166', '167', '170', '171', '172', '173', '174', '175', '176', '177', '200', '201', '202', '203', '204', '205', '206', '207', '210', '211', '212', '213', '214', '215', '216', '217', '220', '221', '222', '223', '224', '225', '226', '227', '230', '23
# ...

# %%
# 뮌히하우젠 수라는 것도 있는데
# 이것은 어떤수의 각각의 수에 각각의 수 만큼 거듭제곱을 해서 더한 값이 그 수와 값이 같으면

# %%
b = 3435
count = 0
for i in str(b) :
    count += int(i) ** int(i)
if count == b :
    print(f'{b} 는 뮈힌하우젠 수 이다')
# Out:
# 3435 는 뮈힌하우젠 수 이다
